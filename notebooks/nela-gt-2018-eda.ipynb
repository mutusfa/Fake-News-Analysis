# %%
from pathlib import Path

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder

from jjuoda_dl4 import utils

# %% [markdown]
# ### Data loads

# %%
BASE_RAW_NELA_GT_2018_PATH = utils.BASE_DATA_DIR / "raw/NELA-GT-2018"

# %%
labels = pd.read_csv(BASE_RAW_NELA_GT_2018_PATH / "labels.csv", index_col=0)
labels.head()
# Out:
#                   NewsGuard, Does not repeatedly publish false content  \
# 21stCenturyWire                                                 NaN
# ABC News                                                        0.0
# AMERICAblog News                                                NaN
# Activist Post                                                   NaN
# Addicting Info                                                  NaN
#
#                   NewsGuard, Gathers and presents information responsibly  \
# 21stCenturyWire                                                 NaN
# ABC News                                                        0.0
# AMERICAblog News                                                NaN
# Activist Post                                                   NaN
# Addicting Info                                                  NaN
#
#                   NewsGuard, Regularly corrects or clarifies errors  \
# 21stCenturyWire                                                 NaN
# ABC News                                                        0.0
# AMERICAblog News                                                NaN
# Activist Post                                                   NaN
# Addicting Info                                                  NaN
#
#                   NewsGuard, Handles the difference between news and opinion responsibly  \
# 21stCenturyWire                                                 NaN
# ABC News                                                        0.0
# AMERICAblog News                                                NaN
# Activist Post                                                   NaN
# Addicting Info                                                  NaN
#
#                   NewsGuard, Avoids deceptive headlines  \
# 21stCenturyWire                                     NaN
# ABC News                                            0.0
# AMERICAblog News                                    NaN
# Activist Post                                       NaN
# Addicting Info                                      NaN
#
#                   NewsGuard, Website discloses ownership and financing  \
# 21stCenturyWire                                                 NaN
# ABC News                                                        0.0
# AMERICAblog News                                                NaN
# Activist Post                                                   NaN
# Addicting Info                                                  NaN
#
#                   NewsGuard, Clearly labels advertising  \
# 21stCenturyWire                                     NaN
# ABC News                                            0.0
# AMERICAblog News                                    NaN
# Activist Post                                       NaN
# Addicting Info                                      NaN
#
#                   NewsGuard, Reveals who's in charge, including any possible conflicts of interest  \
# 21stCenturyWire                                                 NaN
# ABC News                                                        1.0
# AMERICAblog News                                                NaN
# Activist Post                                                   NaN
# Addicting Info                                                  NaN
#
#                   NewsGuard, Provides information about content creators  \
# 21stCenturyWire                                                 NaN
# ABC News                                                        0.0
# AMERICAblog News                                                NaN
# Activist Post                                                   NaN
# Addicting Info                                                  NaN
#
#                   NewsGuard, score  ...  Allsides, community_agree  \
# 21stCenturyWire                NaN  ...                        NaN
# ABC News                      95.0  ...                     8964.0
# AMERICAblog News               NaN  ...                        NaN
# Activist Post                  NaN  ...                        NaN
# Addicting Info                 NaN  ...                        NaN
#
#                   Allsides, community_disagree  Allsides, community_label  \
# 21stCenturyWire                            NaN                        NaN
# ABC News                                6949.0             somewhat agree
# AMERICAblog News                           NaN                        NaN
# Activist Post                              NaN                        NaN
# Addicting Info                             NaN                        NaN
#
#                   BuzzFeed, leaning  PolitiFact, Pants on Fire!  \
# 21stCenturyWire                left                         NaN
# ABC News                        NaN                         NaN
# AMERICAblog News               left                         NaN
# Activist Post                  left                         NaN
# Addicting Info                 left                         NaN
#
#                   PolitiFact, False  PolitiFact, Mostly False  \
# 21stCenturyWire                 NaN                       NaN
# ABC News                        NaN                       NaN
# AMERICAblog News                NaN                       NaN
# Activist Post                   NaN                       NaN
# Addicting Info                  NaN                       NaN
#
#                   PolitiFact, Half-True  PolitiFact, Mostly True  \
# 21stCenturyWire                     NaN                      NaN
# ABC News                            NaN                      NaN
# AMERICAblog News                    NaN                      NaN
# Activist Post                       NaN                      NaN
# Addicting Info                      NaN                      NaN
#
#                   PolitiFact, True
# 21stCenturyWire                NaN
# ABC News                       NaN
# AMERICAblog News               NaN
# Activist Post                  NaN
# Addicting Info                 NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# So labels has sources as rows and columns are some sites providing some kind of labels about the sources.

# %% [markdown]
# ### Label analysis

# %%
labels.isna().mean()
# Out:
# NewsGuard, Does not repeatedly publish false content                                0.561856
# NewsGuard, Gathers and presents information responsibly                             0.561856
# NewsGuard, Regularly corrects or clarifies errors                                   0.561856
# NewsGuard, Handles the difference between news and opinion responsibly              0.561856
# NewsGuard, Avoids deceptive headlines                                               0.561856
# NewsGuard, Website discloses ownership and financing                                0.561856
# NewsGuard, Clearly labels advertising                                               0.561856
# NewsGuard, Reveals who's in charge, including any possible conflicts of interest    0.561856
# NewsGuard, Provides information about content creators                              0.561856
# NewsGuard, score                                                                    0.561856
# NewsGuard, overall_class                                                            0.561856
# Pew Research Center, known_by_40%                                                   0.871134
# Pew Research Center, total                                                          0.871134
# Pew Research Center, consistently_liberal                                           0.871134
# Pew Research Center, mostly_liberal                                                 0.871134
# Pew Research Center, mixed                                                          0.871134
# Pew Research Center, mostly conservative                                            0.871134
# Pew Research Center, consistently conservative                                      0.871134
# Wikipedia, is_fake                                                                  0.974227
# Open Sources, reliable                                                              0.984536
# Open Sources, fake                                                                  0.969072
# Open Sources, unreliable                                                            0.922680
# Open Sources, bias                                                                  0.871134
# Open Sources, conspiracy                                                            0.917526
# Open Sources, hate                                                                  0.989691
# Open Sources, junksci                                                               0.984536
# Open Sources, rumor                                                                 0.989691
# Open Sources, blog                                                                  1.000000
# Open Sources, clickbait                                                             0.927835
# Open Sources, political                                                             0.902062
# Open Sources, satire                                                                0.932990
# Open Sources, state                                                                 0.989691
# Media Bias / Fact Check, label                                                      0.304124
# Media Bias / Fact Check, factual_reporting                                          0.422680
# Media Bias / Fact Check, extreme_left                                               0.304124
# Media Bias / Fact Check, right                                                      0.304124
# Media Bias / Fact Check, extreme_right                                              0.304124
# Media Bias / Fact Check, propaganda                                                 0.304124
# Media Bias / Fact Check, fake_news                                                  0.304124
# Media Bias / Fact Check, some_fake_news                                             0.304124
# Media Bias / Fact Check, failed_fact_checks                                         0.304124
# Media Bias / Fact Check, conspiracy                                                 0.304124
# Media Bias / Fact Check, pseudoscience                                              0.304124
# Media Bias / Fact Check, hate_group                                                 0.304124
# Media Bias / Fact Check, anti_islam                                                 0.304124
# Media Bias / Fact Check, nationalism                                                0.304124
# Allsides, bias_rating                                                               0.664948
# Allsides, community_agree                                                           0.664948
# Allsides, community_disagree                                                        0.664948
# Allsides, community_label                                                           0.670103
# BuzzFeed, leaning                                                                   0.711340
# PolitiFact, Pants on Fire!                                                          0.881443
# PolitiFact, False                                                                   0.881443
# PolitiFact, Mostly False                                                            0.881443
# PolitiFact, Half-True                                                               0.881443
# PolitiFact, Mostly True                                                             0.881443
# PolitiFact, True                                                                    0.881443
# dtype: float64

# %% [markdown]
# #### NewsGuard labels

# %%
plt.figure(figsize=(10, 10))

sns.heatmap(labels.filter(regex="NewsGuard").corr(), annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It's interesting how every feature I'd associate with more responsible news reporting negatively correlates with overall NewsGuard score/overall class.

# %%
labels.loc["FiveThirtyEight"].filter(regex="NewsGuard")
# Out:
# NewsGuard, Does not repeatedly publish false content                                  0.0
# NewsGuard, Gathers and presents information responsibly                               0.0
# NewsGuard, Regularly corrects or clarifies errors                                     0.0
# NewsGuard, Handles the difference between news and opinion responsibly                0.0
# NewsGuard, Avoids deceptive headlines                                                 0.0
# NewsGuard, Website discloses ownership and financing                                  0.0
# NewsGuard, Clearly labels advertising                                                 0.0
# NewsGuard, Reveals who's in charge, including any possible conflicts of interest      0.0
# NewsGuard, Provides information about content creators                                0.0
# NewsGuard, score                                                                    100.0
# NewsGuard, overall_class                                                              1.0
# Name: FiveThirtyEight, dtype: object

# %%
labels.loc["Breitbart"].filter(regex="NewsGuard")
# Out:
# NewsGuard, Does not repeatedly publish false content                                 0.0
# NewsGuard, Gathers and presents information responsibly                              1.0
# NewsGuard, Regularly corrects or clarifies errors                                    0.0
# NewsGuard, Handles the difference between news and opinion responsibly               1.0
# NewsGuard, Avoids deceptive headlines                                                0.0
# NewsGuard, Website discloses ownership and financing                                 1.0
# NewsGuard, Clearly labels advertising                                                0.0
# NewsGuard, Reveals who's in charge, including any possible conflicts of interest     1.0
# NewsGuard, Provides information about content creators                               0.0
# NewsGuard, score                                                                    57.0
# NewsGuard, overall_class                                                             0.0
# Name: Breitbart, dtype: object

# %% [markdown]
# Likely the labels are flipped with 1 in NewsGuard features being not "true", but "negative in this regard".
# It'll be much simpler and less confusing to just use overall class.

# %% [markdown]
# ### Pew Research Center labels

# %%
labels.filter(regex="Pew Research Center").dropna().head()
# Out:
#             Pew Research Center, known_by_40%  Pew Research Center, total  \
# ABC News                                  1.0                         1.0
# Al Jazeera                                1.0                        -1.0
# BBC                                       1.0                         1.0
# Breitbart                                 0.0                         0.0
# Buzzfeed                                  0.0                        -1.0
#
#             Pew Research Center, consistently_liberal  \
# ABC News                                          1.0
# Al Jazeera                                        1.0
# BBC                                               1.0
# Breitbart                                        -1.0
# Buzzfeed                                         -1.0
#
#             Pew Research Center, mostly_liberal  Pew Research Center, mixed  \
# ABC News                                    1.0                         1.0
# Al Jazeera                                  0.0                        -1.0
# BBC                                         1.0                         1.0
# Breitbart                                  -1.0                         0.0
# Buzzfeed                                   -1.0                        -1.0
#
#             Pew Research Center, mostly conservative  \
# ABC News                                         1.0
# Al Jazeera                                      -1.0
# BBC                                              1.0
# Breitbart                                        1.0
# Buzzfeed                                        -1.0
#
#             Pew Research Center, consistently conservative
# ABC News                                              -1.0
# Al Jazeera                                            -1.0
# BBC                                                    0.0
# Breitbart                                              1.0
# Buzzfeed                                              -1.0

# %%
plt.figure(figsize=(10, 10))

sns.heatmap(labels.filter(regex="Pew Research Center").corr(), annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# I don't think I can use Pew's labels.

# %% [markdown]
# #### Wikipedia labels

# %%
labels.filter(regex="Wikipedia").dropna().head()
# Out:
#                      Wikipedia, is_fake
# DC Gazette                          1.0
# FT Westminster Blog                 1.0
# GlobalResearch                      1.0
# Infowars                            1.0
# Natural News                        1.0

# %%
labels.filter(regex="Wikipedia").dropna().describe()
# Out:
#        Wikipedia, is_fake
# count                 5.0
# mean                  1.0
# std                   0.0
# min                   1.0
# 25%                   1.0
# 50%                   1.0
# 75%                   1.0
# max                   1.0

# %% [markdown]
# Five sources are notorious enough to be labeled as fake in wikipedia of all things.

# %% [markdown]
# #### Open Sources labels

# %%
labels.filter(regex="Open Sources").dropna(how="all").head()
# Out:
#                   Open Sources, reliable  Open Sources, fake  \
# 21stCenturyWire                      NaN                 NaN
# AMERICAblog News                     NaN                 NaN
# Activist Post                        NaN                 NaN
# Addicting Info                       NaN                 NaN
# Alternet                             2.0                 NaN
#
#                   Open Sources, unreliable  Open Sources, bias  \
# 21stCenturyWire                        NaN                 NaN
# AMERICAblog News                       NaN                 1.0
# Activist Post                          NaN                 NaN
# Addicting Info                         2.0                 NaN
# Alternet                               NaN                 NaN
#
#                   Open Sources, conspiracy  Open Sources, hate  \
# 21stCenturyWire                        1.0                 NaN
# AMERICAblog News                       NaN                 NaN
# Activist Post                          1.0                 NaN
# Addicting Info                         NaN                 NaN
# Alternet                               NaN                 NaN
#
#                   Open Sources, junksci  Open Sources, rumor  \
# 21stCenturyWire                     NaN                  NaN
# AMERICAblog News                    NaN                  NaN
# Activist Post                       NaN                  NaN
# Addicting Info                      NaN                  NaN
# Alternet                            NaN                  NaN
#
#                   Open Sources, blog  Open Sources, clickbait  \
# 21stCenturyWire                  NaN                      NaN
# AMERICAblog News                 NaN                      2.0
# Activist Post                    NaN                      NaN
# Addicting Info                   NaN                      1.0
# Alternet                         NaN                      NaN
#
#                   Open Sources, political  Open Sources, satire  \
# 21stCenturyWire                       NaN                   NaN
# AMERICAblog News                      NaN                   NaN
# Activist Post                         NaN                   NaN
# Addicting Info                        NaN                   NaN
# Alternet                              1.0                   NaN
#
#                   Open Sources, state
# 21stCenturyWire                   NaN
# AMERICAblog News                  NaN
# Activist Post                     NaN
# Addicting Info                    NaN
# Alternet                          NaN

# %%
labels.filter(regex="Open Sources").dropna(how="all").shape
# Out:
# (71, 13)

# %%
labels.filter(regex="Open Sources").dropna(how="all").describe()
# Out:
#        Open Sources, reliable  Open Sources, fake  Open Sources, unreliable  \
# count                     3.0            6.000000                 15.000000
# mean                      2.0            1.333333                  1.866667
# std                       0.0            0.816497                  0.639940
# min                       2.0            1.000000                  1.000000
# 25%                       2.0            1.000000                  1.500000
# 50%                       2.0            1.000000                  2.000000
# 75%                       2.0            1.000000                  2.000000
# max                       2.0            3.000000                  3.000000
#
#        Open Sources, bias  Open Sources, conspiracy  Open Sources, hate  \
# count           25.000000                 16.000000            2.000000
# mean             1.600000                  1.437500            1.500000
# std              0.763763                  0.727438            0.707107
# min              1.000000                  1.000000            1.000000
# 25%              1.000000                  1.000000            1.250000
# 50%              1.000000                  1.000000            1.500000
# 75%              2.000000                  2.000000            1.750000
# max              3.000000                  3.000000            2.000000
#
#        Open Sources, junksci  Open Sources, rumor  Open Sources, blog  \
# count               3.000000             2.000000                 0.0
# mean                1.333333             1.500000                 NaN
# std                 0.577350             0.707107                 NaN
# min                 1.000000             1.000000                 NaN
# 25%                 1.000000             1.250000                 NaN
# 50%                 1.000000             1.500000                 NaN
# 75%                 1.500000             1.750000                 NaN
# max                 2.000000             2.000000                 NaN
#
#        Open Sources, clickbait  Open Sources, political  Open Sources, satire  \
# count                14.000000                19.000000             13.000000
# mean                  1.714286                 1.157895              1.153846
# std                   0.468807                 0.501460              0.375534
# min                   1.000000                 1.000000              1.000000
# 25%                   1.250000                 1.000000              1.000000
# 50%                   2.000000                 1.000000              1.000000
# 75%                   2.000000                 1.000000              1.000000
# max                   2.000000                 3.000000              2.000000
#
#        Open Sources, state
# count             2.000000
# mean              1.500000
# std               0.707107
# min               1.000000
# 25%               1.250000
# 50%               1.500000
# 75%               1.750000
# max               2.000000

# %%
labels.loc["FiveThirtyEight"].filter(regex="Open Sources")
# Out:
# Open Sources, reliable      NaN
# Open Sources, fake          NaN
# Open Sources, unreliable    NaN
# Open Sources, bias          NaN
# Open Sources, conspiracy    NaN
# Open Sources, hate          NaN
# Open Sources, junksci       NaN
# Open Sources, rumor         NaN
# Open Sources, blog          NaN
# Open Sources, clickbait     NaN
# Open Sources, political     NaN
# Open Sources, satire        NaN
# Open Sources, state         NaN
# Name: FiveThirtyEight, dtype: object

# %%
labels.loc["Breitbart"].filter(regex="Open Sources")
# Out:
# Open Sources, reliable      NaN
# Open Sources, fake          NaN
# Open Sources, unreliable    2.0
# Open Sources, bias          3.0
# Open Sources, conspiracy    NaN
# Open Sources, hate          NaN
# Open Sources, junksci       NaN
# Open Sources, rumor         NaN
# Open Sources, blog          NaN
# Open Sources, clickbait     NaN
# Open Sources, political     1.0
# Open Sources, satire        NaN
# Open Sources, state         NaN
# Name: Breitbart, dtype: object

# %% [markdown]
# So we have any info at all on 71 sources. Numbers likely mean the number of articles that open sources analysed and deemed reliable (or fake, or biased or so on). That's some info but I'd want to use more reliable labels before considering a news source as reliable.

# %% [markdown]
# #### Media Bias / Fact Check labels

# %%
labels.filter(regex="Media Bias / Fact Check").dropna(how="all").head()
# Out:
#                 Media Bias / Fact Check, label  \
# 21stCenturyWire       conspiracy_pseudoscience
# ABC News                      left_center_bias
# Activist Post         conspiracy_pseudoscience
# Addicting Info                       left_bias
# Al Jazeera                    left_center_bias
#
#                  Media Bias / Fact Check, factual_reporting  \
# 21stCenturyWire                                         3.0
# ABC News                                                4.0
# Activist Post                                           2.0
# Addicting Info                                          3.0
# Al Jazeera                                              4.0
#
#                  Media Bias / Fact Check, extreme_left  \
# 21stCenturyWire                                    0.0
# ABC News                                           0.0
# Activist Post                                      0.0
# Addicting Info                                     0.0
# Al Jazeera                                         0.0
#
#                  Media Bias / Fact Check, right  \
# 21stCenturyWire                             0.0
# ABC News                                    0.0
# Activist Post                               0.0
# Addicting Info                              0.0
# Al Jazeera                                  0.0
#
#                  Media Bias / Fact Check, extreme_right  \
# 21stCenturyWire                                     0.0
# ABC News                                            0.0
# Activist Post                                       0.0
# Addicting Info                                      0.0
# Al Jazeera                                          0.0
#
#                  Media Bias / Fact Check, propaganda  \
# 21stCenturyWire                                  0.0
# ABC News                                         0.0
# Activist Post                                    0.0
# Addicting Info                                   0.0
# Al Jazeera                                       0.0
#
#                  Media Bias / Fact Check, fake_news  \
# 21stCenturyWire                                 0.0
# ABC News                                        0.0
# Activist Post                                   0.0
# Addicting Info                                  0.0
# Al Jazeera                                      0.0
#
#                  Media Bias / Fact Check, some_fake_news  \
# 21stCenturyWire                                      0.0
# ABC News                                             0.0
# Activist Post                                        0.0
# Addicting Info                                       0.0
# Al Jazeera                                           0.0
#
#                  Media Bias / Fact Check, failed_fact_checks  \
# 21stCenturyWire                                          0.0
# ABC News                                                 0.0
# Activist Post                                            0.0
# Addicting Info                                           0.0
# Al Jazeera                                               0.0
#
#                  Media Bias / Fact Check, conspiracy  \
# 21stCenturyWire                                  0.0
# ABC News                                         0.0
# Activist Post                                    0.0
# Addicting Info                                   0.0
# Al Jazeera                                       0.0
#
#                  Media Bias / Fact Check, pseudoscience  \
# 21stCenturyWire                                     0.0
# ABC News                                            0.0
# Activist Post                                       0.0
# Addicting Info                                      0.0
# Al Jazeera                                          0.0
#
#                  Media Bias / Fact Check, hate_group  \
# 21stCenturyWire                                  0.0
# ABC News                                         0.0
# Activist Post                                    0.0
# Addicting Info                                   0.0
# Al Jazeera                                       0.0
#
#                  Media Bias / Fact Check, anti_islam  \
# 21stCenturyWire                                  0.0
# ABC News                                         0.0
# Activist Post                                    0.0
# Addicting Info                                   0.0
# Al Jazeera                                       0.0
#
#                  Media Bias / Fact Check, nationalism
# 21stCenturyWire                                   0.0
# ABC News                                          0.0
# Activist Post                                     0.0
# Addicting Info                                    0.0
# Al Jazeera                                        0.0

# %%
labels.filter(regex="Media Bias / Fact Check").dropna(how="all").shape
# Out:
# (135, 14)

# %%
labels.filter(regex="Media Bias / Fact Check").dropna(how="all").describe()
# Out:
#        Media Bias / Fact Check, factual_reporting  \
# count                                  112.000000
# mean                                     3.437500
# std                                      0.681562
# min                                      1.000000
# 25%                                      3.000000
# 50%                                      3.500000
# 75%                                      4.000000
# max                                      5.000000
#
#        Media Bias / Fact Check, extreme_left  Media Bias / Fact Check, right  \
# count                             135.000000                      135.000000
# mean                                0.014815                        0.007407
# std                                 0.121261                        0.086066
# min                                 0.000000                        0.000000
# 25%                                 0.000000                        0.000000
# 50%                                 0.000000                        0.000000
# 75%                                 0.000000                        0.000000
# max                                 1.000000                        1.000000
#
#        Media Bias / Fact Check, extreme_right  \
# count                              135.000000
# mean                                 0.088889
# std                                  0.285643
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Media Bias / Fact Check, propaganda  \
# count                           135.000000
# mean                              0.096296
# std                               0.296096
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        Media Bias / Fact Check, fake_news  \
# count                               135.0
# mean                                  0.0
# std                                   0.0
# min                                   0.0
# 25%                                   0.0
# 50%                                   0.0
# 75%                                   0.0
# max                                   0.0
#
#        Media Bias / Fact Check, some_fake_news  \
# count                               135.000000
# mean                                  0.029630
# std                                   0.170195
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        Media Bias / Fact Check, failed_fact_checks  \
# count                                   135.000000
# mean                                      0.007407
# std                                       0.086066
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        Media Bias / Fact Check, conspiracy  \
# count                           135.000000
# mean                              0.066667
# std                               0.250373
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        Media Bias / Fact Check, pseudoscience  \
# count                              135.000000
# mean                                 0.007407
# std                                  0.086066
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Media Bias / Fact Check, hate_group  \
# count                           135.000000
# mean                              0.014815
# std                               0.121261
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        Media Bias / Fact Check, anti_islam  \
# count                           135.000000
# mean                              0.007407
# std                               0.086066
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        Media Bias / Fact Check, nationalism
# count                            135.000000
# mean                               0.007407
# std                                0.086066
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000

# %%
labels.loc["FiveThirtyEight"].filter(regex="Media Bias / Fact Check")
# Out:
# Media Bias / Fact Check, label                 left_center_bias
# Media Bias / Fact Check, factual_reporting                  4.0
# Media Bias / Fact Check, extreme_left                       0.0
# Media Bias / Fact Check, right                              0.0
# Media Bias / Fact Check, extreme_right                      0.0
# Media Bias / Fact Check, propaganda                         0.0
# Media Bias / Fact Check, fake_news                          0.0
# Media Bias / Fact Check, some_fake_news                     0.0
# Media Bias / Fact Check, failed_fact_checks                 0.0
# Media Bias / Fact Check, conspiracy                         0.0
# Media Bias / Fact Check, pseudoscience                      0.0
# Media Bias / Fact Check, hate_group                         0.0
# Media Bias / Fact Check, anti_islam                         0.0
# Media Bias / Fact Check, nationalism                        0.0
# Name: FiveThirtyEight, dtype: object

# %%
labels.loc["Breitbart"].filter(regex="Media Bias / Fact Check")
# Out:
# Media Bias / Fact Check, label                 questionable_source
# Media Bias / Fact Check, factual_reporting                     NaN
# Media Bias / Fact Check, extreme_left                          0.0
# Media Bias / Fact Check, right                                 0.0
# Media Bias / Fact Check, extreme_right                         1.0
# Media Bias / Fact Check, propaganda                            1.0
# Media Bias / Fact Check, fake_news                             0.0
# Media Bias / Fact Check, some_fake_news                        0.0
# Media Bias / Fact Check, failed_fact_checks                    1.0
# Media Bias / Fact Check, conspiracy                            1.0
# Media Bias / Fact Check, pseudoscience                         0.0
# Media Bias / Fact Check, hate_group                            0.0
# Media Bias / Fact Check, anti_islam                            0.0
# Media Bias / Fact Check, nationalism                           0.0
# Name: Breitbart, dtype: object

# %% [markdown]
# #### Allsides labels

# %%
labels.filter(regex="Allsides").dropna(how="all").head()
# Out:
#            Allsides, bias_rating  Allsides, community_agree  \
# ABC News               Lean Left                     8964.0
# Al Jazeera                Center                     2204.0
# Alternet                    Left                     1314.0
# BBC                       Center                     7527.0
# Breitbart                  Right                    11911.0
#
#             Allsides, community_disagree Allsides, community_label
# ABC News                          6949.0            somewhat agree
# Al Jazeera                        3249.0         somewhat disagree
# Alternet                           595.0            strongly agree
# BBC                               7177.0            somewhat agree
# Breitbart                         6546.0                     agree

# %% [markdown]
# Can't use these to differentiate between reliable sources and not.

# %% [markdown]
# #### BuzzFeed labels

# %%
labels.filter(regex="BuzzFeed").dropna(how="all").head()
# Out:
#                  BuzzFeed, leaning
# 21stCenturyWire               left
# AMERICAblog News              left
# Activist Post                 left
# Addicting Info                left
# Alternet                      left

# %% [markdown]
# Can't use this to distinguish reliable sources from unreliable.

# %% [markdown]
# #### Politifact labels

# %%
labels.filter(regex="PolitiFact").dropna(how="all").head()
# Out:
#                    PolitiFact, Pants on Fire!  PolitiFact, False  \
# Al Jazeera                                0.0                1.0
# Bipartisan Report                         0.0                1.0
# Breitbart                                 2.0                2.0
# Buzzfeed                                  1.0                0.0
# CNN                                       0.0                0.0
#
#                    PolitiFact, Mostly False  PolitiFact, Half-True  \
# Al Jazeera                              0.0                    0.0
# Bipartisan Report                       0.0                    0.0
# Breitbart                               0.0                    0.0
# Buzzfeed                                0.0                    0.0
# CNN                                     1.0                    0.0
#
#                    PolitiFact, Mostly True  PolitiFact, True
# Al Jazeera                             0.0               0.0
# Bipartisan Report                      0.0               0.0
# Breitbart                              1.0               0.0
# Buzzfeed                               0.0               0.0
# CNN                                    0.0               0.0

# %%
(labels.filter(regex="PolitiFact").dropna(how="all") > 0).sum()
# Out:
# PolitiFact, Pants on Fire!    9
# PolitiFact, False             8
# PolitiFact, Mostly False      6
# PolitiFact, Half-True         4
# PolitiFact, Mostly True       3
# PolitiFact, True              2
# dtype: int64

# %% [markdown]
# #### Correlations

# %%
all_sides_encoder = OneHotEncoder(sparse=False).fit(labels[["Allsides, bias_rating"]])

all_sides_one_hot = pd.DataFrame(all_sides_encoder.transform(labels[["Allsides, bias_rating"]]), index=labels.index, columns=all_sides_encoder.get_feature_names_out())
all_sides_one_hot
# Out:
#                   Allsides, bias_rating_Center  \
# 21stCenturyWire                            0.0
# ABC News                                   0.0
# AMERICAblog News                           0.0
# Activist Post                              0.0
# Addicting Info                             0.0
# ...                                        ...
# iPolitics                                  0.0
# oann                                       0.0
# rferl                                      0.0
# sott.net                                   0.0
# theRussophileorg                           0.0
#
#                   Allsides, bias_rating_Lean Left  \
# 21stCenturyWire                               0.0
# ABC News                                      1.0
# AMERICAblog News                              0.0
# Activist Post                                 0.0
# Addicting Info                                0.0
# ...                                           ...
# iPolitics                                     0.0
# oann                                          0.0
# rferl                                         0.0
# sott.net                                      0.0
# theRussophileorg                              0.0
#
#                   Allsides, bias_rating_Lean Right  \
# 21stCenturyWire                                0.0
# ABC News                                       0.0
# AMERICAblog News                               0.0
# Activist Post                                  0.0
# Addicting Info                                 0.0
# ...                                            ...
# iPolitics                                      0.0
# oann                                           0.0
# rferl                                          0.0
# sott.net                                       0.0
# theRussophileorg                               0.0
#
#                   Allsides, bias_rating_Left  Allsides, bias_rating_Right  \
# 21stCenturyWire                          0.0                          0.0
# ABC News                                 0.0                          0.0
# AMERICAblog News                         0.0                          0.0
# Activist Post                            0.0                          0.0
# Addicting Info                           0.0                          0.0
# ...                                      ...                          ...
# iPolitics                                0.0                          0.0
# oann                                     0.0                          0.0
# rferl                                    0.0                          0.0
# sott.net                                 0.0                          0.0
# theRussophileorg                         0.0                          0.0
#
#                   Allsides, bias_rating_nan
# 21stCenturyWire                         1.0
# ABC News                                0.0
# AMERICAblog News                        1.0
# Activist Post                           1.0
# Addicting Info                          1.0
# ...                                     ...
# iPolitics                               1.0
# oann                                    1.0
# rferl                                   1.0
# sott.net                                1.0
# theRussophileorg                        1.0
#
# [194 rows x 6 columns]

# %%
plt.figure(figsize=(10, 10))

count_treshold = len(labels) // 10
corr_threshold = .3

merged = labels.merge(all_sides_one_hot.drop("Allsides, bias_rating_nan", axis="columns"), left_index=True, right_index=True)
merged.drop([
    "NewsGuard, Does not repeatedly publish false content",
    "NewsGuard, Gathers and presents information responsibly",
       "NewsGuard, Regularly corrects or clarifies errors",
       "NewsGuard, Handles the difference between news and opinion responsibly",
       "NewsGuard, Avoids deceptive headlines",
       "NewsGuard, Website discloses ownership and financing",
       "NewsGuard, Clearly labels advertising",
       "NewsGuard, Reveals who's in charge, including any possible conflicts of interest",
       "NewsGuard, Provides information about content creators"
    ], axis=1, inplace=True)
enough_labels = merged.notna().sum() > count_treshold

look_at = merged.loc[:, enough_labels].corrwith(labels["NewsGuard, score"]).abs() > corr_threshold
corr_matrix = merged.loc[:, look_at[look_at].index].corr()

print(look_at.sum())

sns.heatmap(corr_matrix, annot=True, vmin=-1, vmax=1)
# Out:
# 15
# <AxesSubplot:>

# %%
sns.histplot(x="NewsGuard, score", data=labels, binwidth=10, binrange=(0, 100))
# Out:
# <AxesSubplot:xlabel='NewsGuard, score', ylabel='Count'>

# %%
labels["Media Bias / Fact Check, factual_reporting"] < 0
# Out:
# 21stCenturyWire     False
# ABC News            False
# AMERICAblog News    False
# Activist Post       False
# Addicting Info      False
#                     ...
# iPolitics           False
# oann                False
# rferl               False
# sott.net            False
# theRussophileorg    False
# Name: Media Bias / Fact Check, factual_reporting, Length: 194, dtype: bool

# %%
def count_publisher_scores(labels):
    scores = pd.Series(index=labels.index, data=np.zeros(len(labels)))
    # Political leanings correlate well with NewsGuard score,
    # however, I want to avoid biasing model to political stance.
    # So I'm not punishing sources for reporting on conservative issues,
    # even if propaganda/conspiracy theories are more prevelant on the right.

    # every comparison against nan returns False
    scores[labels["NewsGuard, score"] >= 80] += 1
    scores[labels["NewsGuard, score"] <= 30] -= 1

    scores[labels["Pew Research Center, known_by_40%"] > 0] += .5

    scores[labels["Media Bias / Fact Check, factual_reporting"] > 0] += 1
    scores[labels["Media Bias / Fact Check, fake_news"] > 0] -= 1
    scores[labels["Media Bias / Fact Check, propaganda"] > 0] -= .5
    scores[labels["Media Bias / Fact Check, conspiracy"] > 0] -= .5
    scores[labels["Media Bias / Fact Check, pseudoscience"] > 0] -= .5
    scores[labels["Media Bias / Fact Check, failed_fact_checks"] > 0] -= .5

    scores[labels["PolitiFact, True"] > 0] += .5
    scores[labels["PolitiFact, False"] > 0] -= .5
    scores[labels["PolitiFact, Pants on Fire!"] > 0] -= 1

    scores.index.name = "source"
    scores.name = "score"

    return scores

scores = count_publisher_scores(labels)
print(f"Num reliable sources: {(scores >= 2).sum()}\nNum unreliable sources: {(scores <= -2).sum()}")
# Out:
# Num reliable sources: 47
# Num unreliable sources: 5

# %%
sns.histplot(scores, binwidth=.5)
# Out:
# <AxesSubplot:xlabel='score', ylabel='Count'>

# %% [markdown]
# Ok, so I have 5 sources I feel I can label every article as fake;
# Also, I have 47 sources I'd be pretty confident labelling every article as "true news".
# This may need rechecking when we have the model.

# %%
articles = {"path": [], "title": [], "date": [], "source": [], "source_score": []}

for article in Path(BASE_RAW_NELA_GT_2018_PATH / "articles").rglob("*"):
    if article.is_dir():
        continue
    source, date, title = article.name.split("--")
    articles["path"].append(article)
    articles["title"].append(title)
    articles["date"].append(date)
    articles["source"].append(source)
    articles["source_score"].append(scores.loc[source])

articles_df = pd.DataFrame(articles)

# %%
articles_df.to_csv(utils.BASE_DATA_DIR / "interim" / "nela-gt-2018-articles.csv")
scores.to_csv(utils.BASE_DATA_DIR / "interim" / "nela-gt-2018-scores.csv")
